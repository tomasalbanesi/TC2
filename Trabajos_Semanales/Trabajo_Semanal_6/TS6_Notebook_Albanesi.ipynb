# %% [markdown]
# <img src="./img/logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Trabajo semanal 6
# #### Tomas A. Albanesi

# %% [markdown]
# ## Indice de contenidos:
# * [Consigna](#consigna)
# * [Punto 1](#punto1)
# * [Punto 2.a](#punto2a)
# * [Punto 2.b](#punto2b)
# * [Punto 2.c](#punto2c)
# * [Conclusiones generales](#conclusiones)

# %% [markdown]
# ## Consigna <a class="anchor" id="consigna"></a>
#
# <img src="./img/ConsignaEjercicio1.png" width="700" />
# <img src="./img/ConsignaEjercicio2.png" width="2000" />

# %% [markdown]
# ## 1. Calcular los parametros Z del cuadripolo <a class="anchor" id="punto1"></a>

# %% [markdown]
# ### Resolucion analitica <a class="anchor" id="punto1a"></a>

# %%
# Incorporacion y visualizacion de PDF
from IPython.display import IFrame
IFrame("./docs/TS6_Albanesi_Punto1Analitico.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./docs/TS6_Albanesi_Punto1Analitico.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. a. Obtención de transferencia de tensión <a class="anchor" id="punto2a"></a>

# %% [markdown]
# ### Resolucion analitica  <a class="anchor" id="punto2a"></a>

# %%
# Incorporacion y visualizacion de PDF
from IPython.display import IFrame
IFrame("./docs/TS6_Albanesi_Punto2aAnalitico.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./docs/TS6_Albanesi_Punto2aAnalitico.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulacion numerica

# %%
import matplotlib.pyplot as plt
import scipy.signal as sig
import numpy as np
from pytc2.sistemas_lineales import analyze_sys

num = [1]
den = [1,2,3,1]

transfer_f = sig.TransferFunction(num, den)

plt.close('all')
analyze_sys(transfer_f, 'Transferencia')

# %% [markdown]
# ### Simulacion circuital

# %% [markdown]
# <img src="./img/Punto2aCircuito.png" width="700" />
#
# <img src="./img/Punto2aSimulacion.png" width="1000" />

# %% [markdown]
# ## 2. b. Obtención de matriz de admitancias indefinida (MAI) <a class="anchor" id="punto2b"></a>

# %%
# Incorporacion y visualizacion de PDF
from IPython.display import IFrame
IFrame("./docs/TS6_Albanesi_Punto2bAnalitico.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./docs/TS6_Albanesi_Punto2bAnalitico.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. c. Obtención de transferencia de tensión mediante la MAI <a class="anchor" id="punto2c"></a>

# %%
# Incorporacion y visualizacion de PDF
from IPython.display import IFrame
IFrame("./docs/TS6_Albanesi_Punto2cAnalitico.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./docs/TS6_Albanesi_Punto2cAnalitico.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Conclusiones generales <a class="anchor" id="conclusiones"></a>

# %% [markdown]
# Con respecto al primer punto, se pudo verificar que mediante las definiciones de los parametros y aplicando leyes de los circuito basicas, se puede llegar a la obtención de la matriz de parametros, en este caso, los parametros Z de impedancia. Si bien conlleva un trabajo matematico un poco mayor se obtienen correctamente.
#
# Con respecto al segundo ejercicio, se puede observar que hallar la transferencia por el metodo de los parametros T y aplicando propiedades de cuadripolos, o aplicando las propiedades de la matriz de admitancia indefinida (MAI), se llega al mismo resultado. Sin embargo, a medida que el orden del sistema crece, conviene aplicar el metodo de la MAI ya que es mas optimo para la resolucion, y ademas, en la actualidad, se puede resolver mediante los elementos computacionales, al contrario del metodo tradicional de cuadripolos el cual necesita de un mayor esfuerzo matematico y desarrollo.
